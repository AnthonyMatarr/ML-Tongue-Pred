# %% [markdown]
# # Prepare Models and other data for Deployment on Streamlit
#
# Import models from ML workflow and export into app/ dir

# %% [markdown]
# ## Set Up

# %%
import sys

sys.path.append("../")
from src.config import BASE_PATH, SEED
from app.config import CHOSEN_MODEL_DICT
import numpy as np
import pandas as pd
import joblib
from shutil import rmtree
from sklearn.model_selection import train_test_split
import shap
import json

# %% [markdown]
# ## Imports/Exports

# %% [markdown]
# Initialize paths

# %%
def clean_make_dir(directory):
    if directory.exists():
        rmtree(directory)
    directory.mkdir(exist_ok=False, parents=True)


## MODELS
cal_model_output_dir = BASE_PATH / "app" / "models"
clean_make_dir(cal_model_output_dir)

## PIPELINES
pipe_output_dir = BASE_PATH / "app" / "preprocessors"
clean_make_dir(pipe_output_dir)

## FILL IN DATA
fill_output_dir = BASE_PATH / "app" / "fill_data"
clean_make_dir(fill_output_dir)

## ALL PREDS
pred_output_dir = BASE_PATH / "app" / "all_preds"
clean_make_dir(pred_output_dir)

## BIN THRESHOLDS
threshold_output_dir = BASE_PATH / "app" / "bin_thresholds"
clean_make_dir(threshold_output_dir)

## SHAP explainers
shap_output_dir = BASE_PATH / "app" / "shap_explainers"
clean_make_dir(shap_output_dir)

# %% [markdown]
# Import/Export to app dir

# %%
def get_fill_in(outcome_name, preprocessor, dropped_feats):
    """
    Fill in dropped features w/ median (numeric) and mode (categorical) values

    This is arbitrary for OHE & scaling of interface input feats,
    but want reliable vals bc of imputation of missing numerical on interface
    """
    numeric_cols = [
        "AGE",
        "HEIGHT",
        "WEIGHT",
        "PRALBUM",
        "PRWBC",
        "PRHCT",
        "PRPLATE",
        "OPERYR",
        "OPTIME",
    ]
    full_train_data = pd.read_parquet(
        BASE_PATH / "data" / "processed" / f"outcome_{outcome_name}" / "X_train.parquet"
    )
    imputer = preprocessor.named_transformers_["num"]["imputer"]
    medians = imputer.initial_imputer_.statistics_
    median_dict = dict(zip(numeric_cols, medians))
    # 0 is mode for both
    fill_in_dict = {
        "DYSPNEA": "No",
        "RENAFAIL": "No",
    }
    for col in dropped_feats:
        if "DYSPNEA" in col or "RENAFAIL" in col:
            continue
        if col in numeric_cols:
            fill_in_dict[col] = float(median_dict[col])  # type: ignore
        else:
            fill_in_dict[col] = 0  # type: ignore
    return fill_in_dict


# after one-hot encoding
dropped_feats = [
    "RENAFAIL_Yes",
    "RENAFAIL_Unknown(21)",
    "RENAFAIL_No",
    "DYSPNEA_Unknown(21-24)",
    "DYSPNEA_Yes",
    "DYSPNEA_No",
    "TRANSFUS",
    "PAROTID GLAND EXCISION",
    "GASTROSTOMY AND ESOPHAGEAL ACCESS PROCEDURES",
    "ETHNICITY_HISPANIC",
    "ALVEOLAR RIDGE AND GINGIVAL PROCEDURES",
    "DIALYSIS",
    "TONSILLECTOMY AND TONSILLAR REGION PROCEDURES",
    "HXCHF",
    "BLEEDDIS",
    "ASCITES",
    "PHARYNGEAL RESECTION AND RECONSTRUCTION PROCEDURES",
    "URGENCY",
    "PRSEPIS",
    "VENTILAT",
    "MANDIBULAR RESECTION AND RECONSTRUCTION PROCEDURES",
    "SUBMANDIBULAR GLAND EXCISION",
    "STEROID",
    "OPTIME",
]

# %%
## GET OUTCOME PIPELINES, CHOSEN MODELS, AND ASSOCIATED PREDS/THRESHOLDS
for outcome_name, chosen_model in CHOSEN_MODEL_DICT.items():
    print(f"Outcome: {outcome_name}, model: {chosen_model}")
    # ================> Pipelines (shared by all models)
    pipeline = joblib.load(
        BASE_PATH / "data" / "preprocessors" / f"outcome_{outcome_name}_pipeline.joblib"
    )
    joblib.dump(pipeline, pipe_output_dir / f"{outcome_name}_pipeline.joblib")
    # ================> Fill in data
    fill_in_dict = get_fill_in(outcome_name, pipeline, dropped_feats)
    with open(fill_output_dir / f"{outcome_name}.json", "w") as f:
        json.dump(fill_in_dict, f, indent=4)
    # ================> MODELS
    # Calibrated models for predictions
    cal_model = joblib.load(
        BASE_PATH / "models" / "calibrated" / outcome_name / f"{chosen_model}.joblib"
    )
    joblib.dump(
        cal_model, cal_model_output_dir / f"{outcome_name}_{chosen_model}.joblib"
    )
    # ================> All Preds
    test_preds = pd.read_parquet(
        BASE_PATH
        / "results"
        / "app"
        / "all_preds"
        / outcome_name
        / f"{chosen_model}.parquet"
    )
    test_preds.to_parquet(pred_output_dir / f"{outcome_name}_{chosen_model}.parquet")
    # ================> Bin Thresholds
    bin_thresholds = np.load(
        BASE_PATH
        / "results"
        / "app"
        / "bin_thresholds"
        / outcome_name
        / f"{chosen_model}.npz"
    )
    np.savez(
        threshold_output_dir / f"{outcome_name}_{chosen_model}.npz",
        thresholds=bin_thresholds["thresholds"],
    )
    # ================> SHAP explainer
    X_test = pd.read_parquet(
        BASE_PATH
        / "data"
        / "processed_reduced"
        / f"outcome_{outcome_name}"
        / "X_test.parquet"
    )

    # No NN models used
    model_path = (
        BASE_PATH / "models" / "trained" / outcome_name / f"{chosen_model}.joblib"
    )
    un_cal_model = joblib.load(model_path)

    if chosen_model in ["lgbm", "xgb"]:
        print("Using TreeExplainer...")
        explainer = shap.TreeExplainer(
            model=un_cal_model,
            data=X_test,
            feature_perturbation="interventional",
            model_output="raw",
            feature_names=X_test.columns.tolist(),
        )

    elif chosen_model == "lr":
        print("\t Using LinearExplainer...")
        explainer = shap.LinearExplainer(
            un_cal_model,
            X_test,
            feature_names=X_test.columns.tolist(),
            seed=SEED,
        )
    elif chosen_model == "svc":
        print("\t Using KernelExplainer...")
        from scipy.special import expit

        explainer = shap.KernelExplainer(
            lambda X: expit(un_cal_model.decision_function(X)),
            X_test,
            feature_names=X_test.columns.tolist(),
            link="identity",
        )
    elif chosen_model == "stack":
        print("\t Using KernelExplainer...")
        explainer = shap.KernelExplainer(
            model=un_cal_model.predict_proba,
            data=X_test,
            feature_names=X_test.columns.tolist(),
        )
    else:
        raise ValueError(f"Unrecognized model {chosen_model}")

    joblib.dump(explainer, shap_output_dir / f"{outcome_name}.joblib")

# Save feature names
feature_names = X_test.columns.tolist()
joblib.dump(feature_names, shap_output_dir / "feature_names.joblib")
